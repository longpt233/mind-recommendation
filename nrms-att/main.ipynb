# %%
from google.colab import drive
drive._mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/20211/rec-sys/mind-recomendation/nrms-att
# Out:
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/nrms-att

# %%
# !python nrms_train.py
# Out:
# (attention_hidden_dim, 200),(batch_size, 32),(data_format, news),(dropout, 0.2),(epochs, 4),(head_dim, 20),(head_num, 20),(his_size, 50),(learning_rate, 0.0001),(log_file, entity.txt),(loss, cross_entropy_loss),(metrics, ['group_auc', 'mean_mrr', 'ndcg@5;10']),(model_type, nrms_entity),(news_attr, {'title': 30, 'entity': 5}),(npratio, 4),(optimizer, adam),(show_step, 10000),(support_quick_scoring, True),(title_size, 30),(userDict_file, /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/utils/uid2index.pkl),(wordDict_file, /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/utils/word_dict.pkl),(wordEmb_file, /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/utils/embedding.npy),(word_emb_dim, 300)
# load nrms-entity trainer
# Training 7386: : 7386it [20:16,  6.07it/s]
# Run news 1326: : 1326it [00:05, 250.40it/s]
# Run user 2286: : 2286it [01:42, 22.36it/s]
# Run fast evaluation 73152: : 73152it [00:26, 2791.58it/s]
# ...

# %%
import torch.nn as nn 
import torch

m = nn.Softmax(dim=-1)
input = torch.randn(2 , 3, 1)
print(input)

flat = nn.Flatten(input)
print(flat)

output = m(flat)
print(output)
# Out:
# tensor([[[-0.8836],
#          [-1.0803],
#          [ 0.3795]],
#
#         [[ 0.3096],
#          [ 0.5681],
#          [ 0.7548]]])
# Flatten(
#   start_dim=tensor([[[-0.8836],
#            [-1.0803],
#            [ 0.3795]],
#
#           [[ 0.3096],
#            [ 0.5681],
#            [ 0.7548]]]), end_dim=-1
# )
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-45b88be284b1> in <module>()
#       9 print(flat)
#      10
# ---> 11 output = m(flat)
#      12 print(output)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
# ...
