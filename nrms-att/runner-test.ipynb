# %%
from google.colab import drive
drive._mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/recommenders-large
# Out:
# /content/drive/MyDrive/recommenders-large

# %%
# !python nrms_predict.py
# Out:
# (attention_hidden_dim, 200),(batch_size, 32),(data_format, news),(dropout, 0.2),(epochs, 8),(head_dim, 20),(head_num, 20),(his_size, 50),(learning_rate, 0.0001),(log_file, entity.txt),(loss, cross_entropy_loss),(metrics, ['group_auc', 'mean_mrr', 'ndcg@5;10']),(model_type, nrms_entity),(news_attr, {'title': 30, 'entity': 5}),(npratio, 4),(optimizer, adam),(show_step, 10),(support_quick_scoring, True),(title_size, 30),(userDict_file, /content/drive/MyDrive/recommenders-large/mind_dataset/utils/uid2index.pkl),(wordDict_file, /content/drive/MyDrive/recommenders-large/mind_dataset/utils/word_dict.pkl),(wordEmb_file, /content/drive/MyDrive/recommenders-large/mind_dataset/utils/embedding.npy),(word_emb_dim, 300)
# Run news 3781: : 3781it [00:15, 243.91it/s]
# Run user 74086: : 74086it [44:21, 27.84it/s]
# Run fast evaluation 2370727: : 2370727it [15:56, 2478.90it/s]
# 2370727it [02:25, 16281.73it/s]
# inference on category: cost: 3795.1793377399445s.
