# %%
 from google.colab import drive
drive._mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install transformers
# !pip install -U sentence-transformers

# %%
# %cd /content/drive/MyDrive/20211/rec-sys/mind-recomendation/naml
# Out:
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/naml

# %%
import sys
import os
import numpy as np
import zipfile
from tqdm import tqdm 
from tempfile import TemporaryDirectory
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.models.deeprec.deeprec_utils import download_deeprec_resources 
from recommenders.models.newsrec.newsrec_utils import prepare_hparams
from recommenders.models.newsrec.models.naml_lstm import NAMLModel
from recommenders.models.newsrec.io.mind_all_iterator import MINDAllIterator
from recommenders.models.newsrec.io.mind_all_iterator_shuffle import MINDAllIteratorShuffle
from recommenders.models.newsrec.newsrec_utils import get_mind_data_set

print("System version: {}".format(sys.version))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# Using TensorFlow backend.
# System version: 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
# Tensorflow version: 1.15.2

# %% [markdown]
# ## Prepare Parameters

# %%
epochs = 3
seed = 42
batch_size = 32

# Options: demo, small, large
MIND_type = 'small'

# %% [markdown]
# ## Download and load data

# %%
data_path = "/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data"

train_news_file = os.path.join(data_path, MIND_type+'/train', r'news.tsv')
train_behaviors_file = os.path.join(data_path, MIND_type+'/train', r'behaviors.tsv')
valid_news_file = os.path.join(data_path,MIND_type+ '/valid', r'news.tsv')
valid_behaviors_file = os.path.join(data_path,MIND_type+ '/valid', r'behaviors.tsv')


wordEmb_file = os.path.join(data_path, "utils", "embedding.npy")
userDict_file = os.path.join(data_path, "utils", "uid2index.pkl")
wordDict_file = os.path.join(data_path, "utils", "word_dict.pkl")

# add cai nay cho naml 
vertDict_file = os.path.join(data_path, "utils", "vert_dict.pkl")
subvertDict_file = os.path.join(data_path, "utils", "subvert_dict.pkl")

yaml_file = os.path.join(data_path, "utils", r'naml.yaml')

mind_url, mind_train_dataset, mind_dev_dataset, mind_utils = get_mind_data_set(MIND_type)

if not os.path.exists(train_news_file):
    download_deeprec_resources(mind_url, os.path.join(data_path,MIND_type+ '/train'), mind_train_dataset)
    
if not os.path.exists(valid_news_file):
    download_deeprec_resources(mind_url, \
                               os.path.join(data_path,MIND_type+ '/valid'), mind_dev_dataset)
if not os.path.exists(yaml_file):
    download_deeprec_resources(r'https://recodatasets.z20.web.core.windows.net/newsrec/', \
                               os.path.join(data_path, 'utils'), mind_utils)

# %% [markdown]
# ## Create hyper-parameters

# %%
hparams = prepare_hparams(yaml_file, 
                          wordEmb_file=wordEmb_file,
                          wordDict_file=wordDict_file, 
                          userDict_file=userDict_file,
                          vertDict_file=vertDict_file, 
                          subvertDict_file=subvertDict_file,
                          batch_size=batch_size,
                          epochs=epochs)
print(hparams)
# Out:
# HParams object with values {'support_quick_scoring': True, 'dropout': 0.2, 'attention_hidden_dim': 200, 'head_num': 4, 'head_dim': 100, 'filter_num': 400, 'window_size': 3, 'vert_emb_dim': 100, 'subvert_emb_dim': 100, 'gru_unit': 400, 'type': 'ini', 'user_emb_dim': 50, 'learning_rate': 0.0001, 'optimizer': 'adam', 'epochs': 3, 'batch_size': 32, 'show_step': 100000, 'title_size': 30, 'body_size': 50, 'his_size': 50, 'vert_num': 17, 'subvert_num': 249, 'data_format': 'naml', 'npratio': 4, 'metrics': ['group_auc', 'mean_mrr', 'ndcg@5;10'], 'word_emb_dim': 300, 'cnn_activation': 'relu', 'model_type': 'naml', 'dense_activation': 'relu', 'loss': 'cross_entropy_loss', 'wordEmb_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/utils/embedding.npy', 'wordDict_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/utils/word_dict.pkl', 'userDict_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/utils/uid2index.pkl', 'vertDict_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/utils/vert_dict.pkl', 'subvertDict_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/utils/subvert_dict.pkl'}

# %%
# iterator = MINDAllIterator(hparams)  # mind all thì có thêm load cả body nữa

# %%
print(train_news_file)
print(train_behaviors_file)
# Out:
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/train/news.tsv
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/train/behaviors.tsv

# %%
# iterator.load_data_from_file(news_file= train_news_file,behavior_file= train_behaviors_file)

# %%
# import pickle
# with open(wordDict_file, "rb") as f:
#     a = pickle.load(f)

# %%
# len(a)  # lúc load cái từ lên nó đã cho qua một từ điển 60992 từ rồi vcl

# %%
iterator = MINDAllIterator

# %% [markdown]
# ## Train the NAML model

# %%
model = NAMLModel(hparams, iterator, seed=seed)
# Out:
# dau vao new encoder =
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846954e410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# shape vao (?, 50, 82)
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846954e410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846954e410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# Model: "news_encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 82)]         0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 30)           0           input_13[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 50)           0           input_13[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1)            0           input_13[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1)            0           input_13[0][0]
# __________________________________________________________________________________________________
# title_encoder (Model)           (None, 1, 400)       10732000    lambda[0][0]
# __________________________________________________________________________________________________
# body_encoder (Model)            (None, 1, 400)       10732000    lambda_1[0][0]
# __________________________________________________________________________________________________
# vert_encoder (Model)            (None, 1, 400)       42100       lambda_2[0][0]
# __________________________________________________________________________________________________
# subvert_encoder (Model)         (None, 1, 400)       65300       lambda_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 4, 400)       0           title_encoder[1][0]
#                                                                  body_encoder[1][0]
#                                                                  vert_encoder[1][0]
#                                                                  subvert_encoder[1][0]
# __________________________________________________________________________________________________
# att_layer2_2 (AttLayer2)        (None, 400)          80400       concatenate_3[0][0]
# ==================================================================================================
# Total params: 11,360,600
# Trainable params: 11,360,600
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "user_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        [(None, 50, 82)]          0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 50, 400)           21651800
# _________________________________________________________________
# lstm (LSTM)                  (None, 50, 128)           270848
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50, 256)           394240
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 400)               1051200
# =================================================================
# Total params: 13,076,888
# Trainable params: 13,076,888
# Non-trainable params: 0
# _________________________________________________________________
# user summary None
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846954e410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846954e410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846954e410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846954e410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f84c071ff50>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846a7b4090>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7f846954e410>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# news_present shape = (?, 5, 400)  user_present shape = (?, 400)

# %%
# model.model.summary()

# %%
# model._build_naml()[0].summary()

# %%
# print(model.run_eval(valid_news_file, valid_behaviors_file))

# %%
# %%time
model.fit(train_news_file, train_behaviors_file,valid_news_file, valid_behaviors_file)
# Out:
# 7385it [1:20:55,  1.52it/s]
# 42386it [03:07, 226.39it/s]
# 73121it [1:16:45, 15.88it/s]
# 73152it [00:13, 5377.61it/s]
# at epoch 1
# train info: logloss loss:1.404809264581431
# eval info: group_auc:0.6215, mean_mrr:0.2684, ndcg@10:0.3624, ndcg@5:0.2964
# at epoch 1 , train time: 4855.3 eval time: 4895.7
# 155it [01:41,  1.53it/s]

# %%
# %%time
# res_syn = model.run_eval(valid_news_file, valid_behaviors_file)
# print(res_syn)

# %%
# sb.glue("res_syn", res_syn)

# %% [markdown]
# ## Save the model

# %%
model_path = os.path.join(data_path, "model-naml-lstm")
os.makedirs(model_path, exist_ok=True)

model.model.save_weights(os.path.join(model_path, "naml_ckpt"))

# %% [markdown]
# ## Output Prediction File
# This code segment is used to generate the prediction.zip file, which is in the same format in [MIND Competition Submission Tutorial](https://competitions.codalab.org/competitions/24122#learn_the_details-submission-guidelines).
#
# Please change the `MIND_type` parameter to `large` if you want to submit your prediction to [MIND Competition](https://msnews.github.io/competition.html).

# %%
group_impr_indexes, group_labels, group_preds = model.run_fast_eval(valid_news_file, valid_behaviors_file)

# %%
with open(os.path.join(data_path, 'prediction.txt'), 'w') as f:
    for impr_index, preds in tqdm(zip(group_impr_indexes, group_preds)):
        impr_index += 1
        pred_rank = (np.argsort(np.argsort(preds)[::-1]) + 1).tolist()
        pred_rank = '[' + ','.join([str(i) for i in pred_rank]) + ']'
        f.write(' '.join([str(impr_index), pred_rank])+ '\n')

# %%
f = zipfile.ZipFile(os.path.join(data_path, 'prediction.zip'), 'w', zipfile.ZIP_DEFLATED)
f.write(os.path.join(data_path, 'prediction.txt'), arcname='prediction.txt')
f.close()

# %% [markdown]
# ## Reference
# \[1\] Chuhan Wu, Fangzhao Wu, Mingxiao An, Jianqiang Huang, Yongfeng Huang and Xing Xie: Neural News Recommendation with Attentive Multi-View Learning, IJCAI 2019<br>
# \[2\] Wu, Fangzhao, et al. "MIND: A Large-scale Dataset for News Recommendation" Proceedings of the 58th Annual Meeting of the Association for Computational Linguistics. https://msnews.github.io/competition.html <br>
# \[3\] GloVe: Global Vectors for Word Representation. https://nlp.stanford.edu/projects/glove/
