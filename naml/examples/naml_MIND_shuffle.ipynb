# %%
from google.colab import drive
drive._mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install transformers
# !pip install -U sentence-transformers

# %%
# %cd /content/drive/MyDrive/20211/rec-sys/mind-recomendation/naml
# Out:
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/naml

# %%
import sys
import os
import numpy as np
import zipfile
from tqdm import tqdm 
from tempfile import TemporaryDirectory
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.models.deeprec.deeprec_utils import download_deeprec_resources 
from recommenders.models.newsrec.newsrec_utils import prepare_hparams
from recommenders.models.newsrec.models.naml_suffle import NAMLModel
from recommenders.models.newsrec.io.mind_all_iterator import MINDAllIterator
from recommenders.models.newsrec.io.mind_all_iterator_shuffle import MINDAllIteratorShuffle
from recommenders.models.newsrec.newsrec_utils import get_mind_data_set

print("System version: {}".format(sys.version))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
# Tensorflow version: 1.15.2

# %% [markdown]
# ## Prepare Parameters

# %%
epochs = 1
seed = 42
batch_size = 32

# Options: demo, small, large
MIND_type = 'small'

# %% [markdown]
# ## Download and load data

# %%
data_path = data_path = "/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small"

train_news_file = os.path.join(data_path, 'train', r'news.tsv')
train_behaviors_file = os.path.join(data_path, 'train', r'behaviors.tsv')
valid_news_file = os.path.join(data_path, 'valid', r'news.tsv')
valid_behaviors_file = os.path.join(data_path, 'valid', r'behaviors.tsv')
wordEmb_file = os.path.join(data_path, "utils", "embedding_all.npy")
userDict_file = os.path.join(data_path, "utils", "uid2index.pkl")
wordDict_file = os.path.join(data_path, "utils", "word_dict_all.pkl")
vertDict_file = os.path.join(data_path, "utils", "vert_dict.pkl")
subvertDict_file = os.path.join(data_path, "utils", "subvert_dict.pkl")
yaml_file = os.path.join(data_path, "utils", r'naml.yaml')

mind_url, mind_train_dataset, mind_dev_dataset, mind_utils = get_mind_data_set(MIND_type)

if not os.path.exists(train_news_file):
    download_deeprec_resources(mind_url, os.path.join(data_path, 'train'), mind_train_dataset)
    
if not os.path.exists(valid_news_file):
    download_deeprec_resources(mind_url, \
                               os.path.join(data_path, 'valid'), mind_dev_dataset)
if not os.path.exists(yaml_file):
    download_deeprec_resources(r'https://recodatasets.z20.web.core.windows.net/newsrec/', \
                               os.path.join(data_path, 'utils'), mind_utils)

# %% [markdown]
# ## Create hyper-parameters

# %%
hparams = prepare_hparams(yaml_file, 
                          wordEmb_file=wordEmb_file,
                          wordDict_file=wordDict_file, 
                          userDict_file=userDict_file,
                          vertDict_file=vertDict_file, 
                          subvertDict_file=subvertDict_file,
                          batch_size=batch_size,
                          epochs=epochs)
print(hparams)
# Out:
# HParams object with values {'support_quick_scoring': True, 'dropout': 0.2, 'attention_hidden_dim': 200, 'head_num': 4, 'head_dim': 100, 'filter_num': 400, 'window_size': 3, 'vert_emb_dim': 100, 'subvert_emb_dim': 100, 'gru_unit': 400, 'type': 'ini', 'user_emb_dim': 50, 'learning_rate': 0.0001, 'optimizer': 'adam', 'epochs': 1, 'batch_size': 32, 'show_step': 100000, 'title_size': 384, 'body_size': 50, 'his_size': 50, 'vert_num': 17, 'subvert_num': 249, 'data_format': 'naml', 'npratio': 4, 'metrics': ['group_auc', 'mean_mrr', 'ndcg@5;10'], 'word_emb_dim': 300, 'cnn_activation': 'relu', 'model_type': 'naml', 'dense_activation': 'relu', 'loss': 'cross_entropy_loss', 'wordEmb_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/utils/embedding_all.npy', 'wordDict_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/utils/word_dict_all.pkl', 'userDict_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/utils/uid2index.pkl', 'vertDict_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/utils/vert_dict.pkl', 'subvertDict_file': '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/utils/subvert_dict.pkl'}

# %%
# iterator = MINDAllIterator(hparams)  # mind all thì có thêm load cả body nữa

# %%
print(train_news_file)
print(train_behaviors_file)
# Out:
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/train/news.tsv
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data/small/train/behaviors.tsv

# %%
# iterator.load_data_from_file(news_file= train_news_file,behavior_file= train_behaviors_file)

# %%
# import pickle
# with open(wordDict_file, "rb") as f:
#     a = pickle.load(f)

# %%
# len(a)  # lúc load cái từ lên nó đã cho qua một từ điển 60992 từ rồi vcl

# %%
# iterator = MINDAllIterator

iterator = MINDAllIteratorShuffle

# %% [markdown]
# ## Train the NAML model

# %%
model = NAMLModel(hparams, iterator, seed=seed)
# Out:
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb752fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb752fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb752fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb803850>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb752fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb752fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb803850>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb752fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb752fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff6700c6dd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5ec9ce2d0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method AttLayer2.call of <recommenders.models.newsrec.models.layers.AttLayer2 object at 0x7ff5eb752fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# (?, 5, 400) (?, 400)

# %%
# model.model.summary()

# %%
# model._build_naml()[0].summary()

# %%
# print(model.run_eval(valid_news_file, valid_behaviors_file))

# %%
# %%time
model.fit(train_news_file, train_behaviors_file,valid_news_file, valid_behaviors_file)
# Out:
# 7385it [1:14:25,  1.65it/s]
# 42386it [01:51, 378.62it/s]
# 73121it [08:02, 151.56it/s]
# 73152it [00:10, 7056.05it/s]
# at epoch 1
# train info: logloss loss:1.3723789406371585
# eval info: group_auc:0.6387, mean_mrr:0.2914, ndcg@10:0.3869, ndcg@5:0.323
# at epoch 1 , train time: 4465.5 eval time: 670.5
# CPU times: user 1h 9min 22s, sys: 1min 25s, total: 1h 10min 48s
# Wall time: 1h 25min 35s

# %%
# %%time
# res_syn = model.run_eval(valid_news_file, valid_behaviors_file)
# print(res_syn)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs

# %%
# sb.glue("res_syn", res_syn)

# %% [markdown]
# ## Save the model

# %%
model_path = os.path.join(data_path, "model-naml-lstm")
os.makedirs(model_path, exist_ok=True)

model.model.save_weights(os.path.join(model_path, "naml_ckpt"))

# %% [markdown]
# ## Output Prediction File
# This code segment is used to generate the prediction.zip file, which is in the same format in [MIND Competition Submission Tutorial](https://competitions.codalab.org/competitions/24122#learn_the_details-submission-guidelines).
#
# Please change the `MIND_type` parameter to `large` if you want to submit your prediction to [MIND Competition](https://msnews.github.io/competition.html).

# %%
group_impr_indexes, group_labels, group_preds = model.run_fast_eval(valid_news_file, valid_behaviors_file)
# Out:
# 42386it [01:48, 389.21it/s]
# 73121it [07:55, 153.83it/s]
# 73152it [00:11, 6435.69it/s]

# %%
with open(os.path.join(data_path, 'prediction.txt'), 'w') as f:
    for impr_index, preds in tqdm(zip(group_impr_indexes, group_preds)):
        impr_index += 1
        pred_rank = (np.argsort(np.argsort(preds)[::-1]) + 1).tolist()
        pred_rank = '[' + ','.join([str(i) for i in pred_rank]) + ']'
        f.write(' '.join([str(impr_index), pred_rank])+ '\n')
# Out:
# 73152it [00:01, 49844.31it/s]

# %%
f = zipfile.ZipFile(os.path.join(data_path, 'prediction.zip'), 'w', zipfile.ZIP_DEFLATED)
f.write(os.path.join(data_path, 'prediction.txt'), arcname='prediction.txt')
f.close()

# %% [markdown]
# ## Reference
# \[1\] Chuhan Wu, Fangzhao Wu, Mingxiao An, Jianqiang Huang, Yongfeng Huang and Xing Xie: Neural News Recommendation with Attentive Multi-View Learning, IJCAI 2019<br>
# \[2\] Wu, Fangzhao, et al. "MIND: A Large-scale Dataset for News Recommendation" Proceedings of the 58th Annual Meeting of the Association for Computational Linguistics. https://msnews.github.io/competition.html <br>
# \[3\] GloVe: Global Vectors for Word Representation. https://nlp.stanford.edu/projects/glove/
