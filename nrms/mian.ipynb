# %%
from google.colab import drive
drive._mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/20211/rec-sys/mind-recomendation/nrms
# Out:
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/nrms

# %%
# !ls
# Out:
# config.json	  mian.ipynb	nrms_predict.py  reco_utils	   utils
# configuration.py  mind_dataset	nrms_train.py	 requirements.txt

# %%
# !python
