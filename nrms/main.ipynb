# %%
from google.colab import drive
drive._mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/20211/rec-sys/mind-recomendation/nrms
# Out:
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/nrms

# %%
# !python nrms_train.py
# Out:
# (attention_hidden_dim, 200),(batch_size, 32),(data_format, news),(device_id, 0),(dropout, 0.2),(epochs, 1),(head_dim, 20),(head_num, 20),(his_size, 50),(learning_rate, 0.0001),(loss, cross_entropy_loss),(metrics, ['group_auc', 'mean_mrr', 'ndcg@5;10']),(model_class, nrms),(model_type, nrms),(news_attr, {'title': 30}),(npratio, 4),(optimizer, adam),(show_step, 10),(support_quick_scoring, True),(title_size, 30),(trainer, ),(userDict_file, /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data-nrms/utils/uid2index.pkl),(wordDict_file, /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data-nrms/utils/word_dict.pkl),(wordEmb_file, /content/drive/MyDrive/20211/rec-sys/mind-recomendation/data-nrms/utils/embedding.npy),(word_emb_dim, 300)
# Training 6929: : 6929it [22:41,  5.18it/s]
