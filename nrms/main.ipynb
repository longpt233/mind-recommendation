# %%
from google.colab import drive
drive._mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/20211/rec-sys/mind-recomendation/nrms
# Out:
# /content/drive/MyDrive/20211/rec-sys/mind-recomendation/nrms

# %%
# !python nrms_train.py
# Out:
# Traceback (most recent call last):
#   File "nrms_train.py", line 20, in <module>
#     trainer = load_trainer(**config)
#   File "/content/drive/My Drive/20211/rec-sys/mind-recomendation/nrms/configuration.py", line 77, in load_trainer
#     hparams = get_params(yaml_name, device_id, model_class)
#   File "/content/drive/My Drive/20211/rec-sys/mind-recomendation/nrms/configuration.py", line 70, in get_params
#     epochs=epochs, show_step=10, userDict_file=get_user_dic_path(), model_class=model_class)
#   File "/content/drive/My Drive/20211/rec-sys/mind-recomendation/nrms/reco_utils/recommender/newsrec/newsrec_utils.py", line 244, in prepare_hparams
#     config = load_yaml(yaml_file)
#   File "/content/drive/My Drive/20211/rec-sys/mind-recomendation/nrms/reco_utils/recommender/deeprec/deeprec_utils.py", line 309, in load_yaml
#     with open(filename, "r") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/20211/rec-sys/mind-recomendation/data-nrms/utils/nrms.yaml'
